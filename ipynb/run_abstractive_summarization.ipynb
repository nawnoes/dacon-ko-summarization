# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r "/content/drive/My Drive/Colab Notebooks/dacon-ko-summation/requirements.txt"
# Out:
# ...
#      |████████████████████████████████| 778kB 5.3MB/s
# ...
#      |████████████████████████████████| 3.0MB 13.1MB/s
# ...
#      |████████████████████████████████| 1.1MB 32.7MB/s
# ...
#      |████████████████████████████████| 890kB 30.6MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=9cd283cfb04b0b6d42f057f3b2c20d591b2b7de3cb1a0b6c48337ece790c1dea
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Wed Dec  9 04:23:39 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    30W / 250W |     10MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/dacon-ko-summation/run_abstractive_summarization.py"
# Out:
# 2020-12-09 04:23:40.758000: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Downloading: 100% 920k/920k [00:00<00:00, 13.1MB/s]
# Downloading: 100% 849k/849k [00:00<00:00, 11.5MB/s]
# Downloading: 100% 85.0/85.0 [00:00<00:00, 71.5kB/s]
# Downloading: 100% 109/109 [00:00<00:00, 57.8kB/s]
# 100% 9987/9987 [00:17<00:00, 570.92it/s]
# Downloading: 100% 577/577 [00:00<00:00, 387kB/s]
# Downloading: 100% 510M/510M [00:09<00:00, 56.5MB/s]
# 100% 9987/9987 [3:55:32<00:00,  1.42s/it]
